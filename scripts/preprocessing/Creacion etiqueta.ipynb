# %% [markdown]
# ### **Imágenes conjunto Entrenamiento**

# %% [markdown]
# La información del conjunto de entrenamiento se encuentra separada en carpetas, una para cada categoría, con un total de 102. Se realiza una iteración sobre cada categoría, para posteriormente guardar la respectiva etiqueta en *Y_train*, la cual es extraída del nombre de la ruta de cada categoría.

# %%
labels = []

for i in range(1,102,1):
    cat_path = f"dataset/102 flower/flowers/train/{i}/"
    for im_path in os.listdir(cat_path):

        labels.append(i)

Y_train = np.array(labels)

# %% [markdown]
# ### **Imágenes conjunto Validación**

# %% [markdown]
# La información del conjunto de entrenamiento se encuentra separada en carpetas, una para cada categoría, con un total de 102. Se realiza una iteración sobre cada categoría, para posteriormente guardar la respectiva etiqueta en *Y_Valid*, la cual es extraída del nombre de la ruta de cada categoría.

# %%
all_images = []

for i in range(1,102,1):
    cat_path = f"dataset/102 flower/flowers/valid/{i}/"
    for im_path in os.listdir(cat_path):

        labels.append(i)

Y_valid = np.array(labels)

# %% [markdown]
# ### **Imagenes Conjunto Test**

# %% [markdown]
# La información del conjunto de entrenamiento se encuentra separada en carpetas, una para cada categoría, con un total de 102. Se realiza una iteración sobre cada categoría, para posteriormente guardar la respectiva etiqueta en *Y_test*, la cual es extraída del nombre de la ruta de cada categoría.

# %%
labels = []

for i in range(1,102,1):
    cat_path = f"dataset/102 flower/flowers/test/{i}/"
    for im_path in os.listdir(cat_path):

        labels.append(i)

Y_test = np.array(labels)
